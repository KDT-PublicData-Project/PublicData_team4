# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
allDF1 = pd.read_excel('../../fixedData/allArea1.xlsx', header=[0,1])
allDF1.fillna(method='ffill', inplace=True)
allDF1
# Out:
#    행정구역별                         산업별        사업체구분별     2020              2021  \
#    행정구역별                         산업별        사업체구분별 사업체수 (개) 종사자수 (명) 사업체수 (개)
# 0     서울        　　　　　　소프트웨어 개발 및 공급업             계    21654   186005    21981
# 1     서울        　　　　　　소프트웨어 개발 및 공급업         단독사업체    20361   140418    20174
# 2     서울        　　　　　　소프트웨어 개발 및 공급업       본사,본점 등      764    32520     1022
# 3     서울        　　　　　　소프트웨어 개발 및 공급업  공장,지사(점),영업소      529    13067      785
# 4     서울  　　　컴퓨터 프로그래밍, 시스템 통합 및 관리업             계     9536    97675     9822
# ..   ...                         ...           ...      ...      ...      ...
# 91    강원  　　　컴퓨터 프로그래밍, 시스템 통합 및 관리업  공장,지사(점),영업소       14       59       13
# 92    강원                   　　　정보서비스업             계      106      728      301
# 93    강원                   　　　정보서비스업         단독사업체       98      215      295
# 94    강원                   　　　정보서비스업       본사,본점 등        3      494        2
# ...

# %%
allDF2 = pd.read_excel('../../fixedData/allArea2.xlsx', header=[0,1])
allDF2.fillna(method='ffill', inplace=True)
allDF2
# Out:
#     행정구역별                   산업별      종사자규모별     2020              2021  \
#     행정구역별                   산업별      종사자규모별 사업체수 (개) 종사자수 (명) 사업체수 (개)
# 0      서울  　　　　　　소프트웨어 개발 및 공급업           계    21654   186005    21981
# 1      서울  　　　　　　소프트웨어 개발 및 공급업      1 - 4명    15652    23036    15497
# 2      서울  　　　　　　소프트웨어 개발 및 공급업      5 - 9명     2478    16301     2627
# 3      서울  　　　　　　소프트웨어 개발 및 공급업    10 - 19명     1701    22869     1821
# 4      서울  　　　　　　소프트웨어 개발 및 공급업    20 - 49명     1164    34573     1296
# ..    ...                   ...         ...      ...      ...      ...
# 169    강원             　　　정보서비스업      5 - 9명        8       47        3
# 170    강원             　　　정보서비스업    10 - 19명        2        X        5
# 171    강원             　　　정보서비스업    20 - 49명        1        X        3
# 172    강원             　　　정보서비스업  300 - 499명        1        X        -
# 173    강원             　　　정보서비스업  500 - 999명        -        -        1
#
#                  2022
# ...

# %%
seoulCurrent = pd.read_excel('../../fixedData/seoulCurrent.xlsx', header=[0,1])
seoulCurrent
# Out:
# C:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                    산업별(1)     2018                                          \
#                    산업별(1) 현재인원 (명) 해당직무 입사 3년차 연봉 (만원) 고용안전성 (점) 발전가능성 (점)
# 0                       계   255928                4232       3.8       3.8
# 1                      기계     2838                5397       3.4       3.5
# 2                   디스플레이      111                3590       3.5       3.8
# 3                     반도체      837                4493       3.4       3.5
# 4                  바이오ㆍ헬스     1597                3905       3.7       3.7
# 5                      섬유     4672                3272       3.6       3.4
# 6                     자동차        -                   -         -         -
# ...

# %%
seoulCurrent.columns
# Out:
# MultiIndex([('산업별(1)',              '산업별(1)'),
#             (  '2018',            '현재인원 (명)'),
#             (  '2018', '해당직무 입사 3년차 연봉 (만원)'),
#             (  '2018',           '고용안전성 (점)'),
#             (  '2018',           '발전가능성 (점)'),
#             (  '2019',            '현재인원 (명)'),
#             (  '2019', '해당직무 입사 3년차 연봉 (만원)'),
#             (  '2019',           '고용안전성 (점)'),
#             (  '2019',           '발전가능성 (점)'),
#             (  '2020',            '현재인원 (명)'),
#             (  '2020', '해당직무 입사 3년차 연봉 (만원)'),
#             (  '2020',           '고용안전성 (점)'),
#             (  '2020',           '발전가능성 (점)'),
#             (  '2021',            '현재인원 (명)'),
#             (  '2021', '해당직무 입사 3년차 연봉 (만원)'),
#             (  '2021',           '고용안전성 (점)'),
#             (  '2021',           '발전가능성 (점)'),
#             (  '2022',            '현재인원 (명)'),
#             (  '2022', '해당직무 입사 3년차 연봉 (만원)'),
#             (  '2022',           '고용안전성 (점)'),
# ...

# %%
seoulNeed = pd.read_excel('../../fixedData/seoulNeed.xlsx', header=[0,1])
seoulExpect = pd.read_excel('../../fixedData/seoulExpect.xlsx', header=[0,1])
ggCurrent = pd.read_excel('../../fixedData/ggCurrent.xlsx', header=[0,1])
ggNeed = pd.read_excel('../../fixedData/ggNeed.xlsx', header=[0,1])
ggExpect = pd.read_excel('../../fixedData/ggExpect.xlsx', header=[0,1])
daeguCurrent = pd.read_excel('../../fixedData/daeguCurrent.xlsx', header=[0,1])
daeguNeed = pd.read_excel('../../fixedData/daeguNeed.xlsx', header=[0,1])
daeguExpect = pd.read_excel('../../fixedData/daeguExpect.xlsx', header=[0,1])
# Out:
# C:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...
